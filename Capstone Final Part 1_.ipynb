# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# The first goal of this analisis is locate the best place for make a  **Store** or build a **Market place** in Boston ,US.
#
# I'll execute the next tasks :
#
# * Choose the safest place by analisis of crime data on the city since 2017
# * Locate the place when it's most probably opening a new Store/Market place
# * Locate the neighborhood most prepend for crime events
#
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# # Data Section

# %% [markdown]
# **Then , i'm list the Datasets and Geo tools for achieve this goal**}
#
# * Foursquare API
# * Kaggle - Crimes in Boston (https://www.kaggle.com/ankkur13/boston-crime-data/download)
# * Folium for make interactive maps
# * Boston Location data (42.361145 , -71.057083 )
